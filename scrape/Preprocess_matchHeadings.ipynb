# %%
import pickle

with open('all_file_headings_mapping.pickle', 'rb') as f:
    x = pickle.load(f)

# %%
x['76.txt']
# Out:
# ['Search form',
#  'Frequently Asked Questions',
#  'Please see the general institute FAQ on the status of IIIT-Delhi, its accreditation, financial model, etc. which are available from the homepage of the institute. This FAQ is mostly about the B.Tech admission for 2017.',
#  '1. What is the status of IIIT-Delhi, is it recognized by UGC/AICTE, does it have any relationship with IP university, etc?',
#  '2. What is the source of latest information about the Admission, Institute, etc.? ',
#  '3. When will the applications start? ',
#  '4. When and where will the list of selected candidates be displayed? ',
#  'Eligibility Related',
#  '5. I got less than 80% in Mathematics in XII, but my overall marks are more than 80%, will I be eligible for admission in IIIT-Delhi ?',
#  '6. I obtained 79.99% - am I eligible?',
#  '7. I have taken Math, but have not done Physics or Chemistry in my XII Boards. I have got more than 80% in Math, and my overall percentage is also more than 80%. Am I eligible?',
#  '8.\tI have 80% in Maths and 80% in aggregate which include Physics and Chemistry.  I want to apply to B.Tech.(CSD) and B.Tech.(ITSS). Which mode of admission should I apply through?',
#  '9. I have done my XII from IB board. Am I eligible to apply?',
#  '10. Why is the eligibility criteria rather high in marks?',
#  '11. Are there any seats reserved for Central/State Board Topper candidates?',
#  '12. Who is a “Delhi candidate”?',
#  '13. Are schools located in Noida/Gurgaon and other places in NCR Delhi but outside New Delhi considered as Delhi school?',
#  '14. Whether students passing 12th as a private candidate (through open schooling) are eligible. If Yes, how their region i.e. Delhi or Outside Delhi will be determined.',
#  '15. I have taken up improvement exam and now have 80% or above marks in mathematics and aggregate. Can I apply?',
#  '16. Can the expelled/debarred students be considered for admission?',
#  "17.  I don't have Computer Science in class 12th. Am I eligible for admission to B.Tech(CSE)?",
#  '18. Can a student who has done schooling from Delhi apply under Outside Delhi Quota?',
#  '19. Is there any other source of information regarding the admissions other than the website?',
#  '20. Any photocopy of the certificate need to be attached along with the application form or not?',
#  '21. What is the source of latest information about the exam, Institute, etc.?',
#  '22. Which degree will be awarded? What is the duration?',
#  '23. Where can I find the placement record?',
#  '24. What is the fee per annum?',
#  '25. Is there any fee waiver?',
#  '26. How do I pay the application fee?',
#  '27. Is there any management quota?',
#  '28. I passed class XII in 2016, can I apply?',
#  '29. When to apply for admission, etc.?',
#  '30. Do you have any quota for sports, arts & culture or Olympiads?',
#  '31. Where can I get the details of UCEED?',
#  '32. Where can  I get the details of admission through IIITD Counselling?',
#  '33. Is the transport facility (college bus) available?',
#  '34. Are there some seats for Foreign Nationals/PIOs/NRIs',
#  '35. How Outside Delhi Students can apply for admission to B.Tech programs at IIITD?']

# %%
fdatapath= "C:\\Users\\hpunetha\\PycharmProjects\\Chatbot\\Solr\\preprocess\\website_scraped_text_new_lxml"
foutputpath = "C:\\Users\\hpunetha\\PycharmProjects\\Chatbot\\Solr\\preprocess\\out"

# %%
import os
pathListing = os.walk(fdatapath)


newdict ={}


for root,dirlist,filelist in pathListing:
        for filename in filelist:
            headdict ={}
            pathvar = os.path.join(root,filename)
#             print(pathvar)
            fname= os.path.basename(pathvar)
#             print(fname)
            text=""
            
            
            
#             ########Test Input
            fname="76.txt"
            pathvar="C:\\Users\\hpunetha\\PycharmProjects\\Chatbot\\Solr\\preprocess\\website_scraped_text_new_lxml\\76.txt"
#             #####input end
            
            totlen = len(x[fname])
            for headindex in range(totlen):
                heading = x[fname][headindex]
                last=False
                found=False
                if(headindex==totlen-1):
                    last=True
                
                
                
                with open(pathvar, encoding='utf8') as f:
    #                 text = f.read()
    #             print(text)
                    filltext = ""
                    for line in f:
                        if heading.strip(' \n') == line.strip(' \n'):
                            found= True
                            continue
                        if found:                           
                            if last==False:
                                nexthead = x[fname][headindex+1]
                                if nexthead.strip(' \n') != line.strip(' \n'):
                                    filltext += line
                                else:
                                    found=False
                                    break
                            else:
                                filltext += line
                    
                    print("=======================================")
                    print("heading=> ",heading)
                    print("text=> ",filltext)
                    print("=======================================")
                    headdict[heading]=filltext
                    
            import json
            outpath = foutputpath + "\\" +fname
            with open(outpath + ".json", 'w') as outfile:
                json.dump(headdict, outfile)
            print("*********done for ",fname)
            break
        break
# Out:
# =======================================
# heading=>  Search form
# text=>
# =======================================
# =======================================
# heading=>  Frequently Asked Questions
# text=>
#
#
#
#
# =======================================
# =======================================
# heading=>  Please see the general institute FAQ on the status of IIIT-Delhi, its accreditation, financial model, etc. which are available from the homepage of the institute. This FAQ is mostly about the B.Tech admission for 2017.
# text=>  1. What is the status of IIIT-Delhi, is it recognized by UGC/AICTE, does it have any relationship with IP university, etc?See on Institute FAQ Page.    (Add new programs in Institute page)
# 2. What is the source of latest information about the Admission, Institute, etc.? Latest information is available on https://iiitd.ac.in/ , www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/
# 3. When will the applications start? Online application process will start from 10th June 2017 (tentative)
# 4. When and where will the list of selected candidates be displayed? For Admission through JAC - All the results of provisionally selected candidates will be displayed on www.jacdelhi.nic.in For Admission through UCEED - All the results of provisionally selected candidates will be displayed on http://www.iitb.ac.in/uceed/2017/For Admission through IIITD counselling - All the results of provisionally selected candidates will be displayed on IIIT-D Website
# Eligibility Related
# 5. I got less than 80% in Mathematics in XII, but my overall marks are more than 80%, will I be eligible for admission in IIIT-Delhi ?No. A student is eligible only if he/she: (i) has obtained 80% or more in Mathematics, AND (ii) has obtained 80% or more aggregate score of best five subjects including maths.
# 6. I obtained 79.99% - am I eligible?No, you are not eligible for admissions in IIIT-Delhi even if your percentage is short by .1% or one mark.
# 7. I have taken Math, but have not done Physics or Chemistry in my XII Boards. I have got more than 80% in Math, and my overall percentage is also more than 80%. Am I eligible?Yes, you are eligible for admission to some seats of B.Tech(CSD) and B.Tech(ITSS) through UCEED and IIITD Counselling.
# 8.	I have 80% in Maths and 80% in aggregate which include Physics and Chemistry.  I want to apply to B.Tech.(CSD) and B.Tech.(ITSS). Which mode of admission should I apply through?Students having Physics, Chemistry and Mathematics in Class XII, willing to apply for B.Tech(CSD) program can apply through JAC and UCEED both. However, if at any point of time a candidate is getting a seat in both processes, he/she will have to withdraw one.Students having Physics, Chemistry and Mathematics in Class XII, willing to apply for B.Tech.(ITSS)  can apply only  through JAC.
# 9. I have done my XII from IB board. Am I eligible to apply?Yes, IB Board is considered equivalent to CBSE. However, before you are granted admission, you will have to show that you satisfy the eligibility criteria. If your Board does not give percentages, then you will have to show an official conversion to percentages.
# 10. Why is the eligibility criteria rather high in marks?To ensure that students have the necessary background in mathematics and overall, the eligibility criteria has been kept at this level. Another reason is that IIIT Delhi has very limited seats, and it is necessary to restrict the number of applicants to a reasonable number.
# 11. Are there any seats reserved for Central/State Board Topper candidates?No, none of the seats are reserved for Central/State Board Topper candidates.
# 12. Who is a “Delhi candidate”?The students who have undertaken qualifying exams (i.e. 12th) from the schools located in Delhi (having PIN CODE of Delhi), irrespective of the location of their hometown, would be considered as "Delhi Candidate". Students belonging to delhi but studying in schools outside delhi will be considered as outside delhi candidates.
# 13. Are schools located in Noida/Gurgaon and other places in NCR Delhi but outside New Delhi considered as Delhi school?No, "Delhi" candidates must have undertaken qualifying exams (i.e. XIIth) from the schools having PIN CODE of Delhi.
# 14. Whether students passing 12th as a private candidate (through open schooling) are eligible. If Yes, how their region i.e. Delhi or Outside Delhi will be determined.Yes, students passing 12th as a private candidate (through open schooling) are eligible to apply provided they satisfy other eligibility criteria. The region from which they can apply i.e. Delhi or Outside Delhi will be determined on the basis of the location of their examination centre.
# 15. I have taken up improvement exam and now have 80% or above marks in mathematics and aggregate. Can I apply?Yes, students who have taken up improvement exam and have now secured 80% or above marks in mathematics and aggregate are eligible to apply provided they satisfy all other eligibility criteria.
# 16. Can the expelled/debarred students be considered for admission?Students expelled from any academic institute are not eligible for admission.
# 17.  I don't have Computer Science in class 12th. Am I eligible for admission to B.Tech(CSE)?Yes, as far as you had mathematics, physics and chemistry as your Class XII standard subjects.
# 18. Can a student who has done schooling from Delhi apply under Outside Delhi Quota?No, if you have done XII from Delhi school you can apply as a Delhi candidate only
# 19. Is there any other source of information regarding the admissions other than the website?Website is the primary source of all the information regarding admission. Please also visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/ for details..
# 20. Any photocopy of the certificate need to be attached along with the application form or not?No certificates need to be sent - they will be checked at the time of counselling.
# 21. What is the source of latest information about the exam, Institute, etc.?Latest information is available on the Institute website. Pls also refer www.jacdelhi.nic.in  and http://www.iitb.ac.in/uceed/2017/.
# 22. Which degree will be awarded? What is the duration?IIIT Delhi awards B.Tech. (CSE), B.Tech(ECE), B.Tech (CSAM), B.Tech(CSD) and B.Tech(ITSS) degrees. The duration of the program is 4 years.
# 23. Where can I find the placement record?Placement record of the institute is available on the placement page of our website.
# 24. What is the fee per annum?Please refer B.Tech admission brochure 2017.
# 25. Is there any fee waiver?Please refer the B.Tech admission page and brochure 2017 for income-linked fee waivers/scholarships.
# 26. How do I pay the application fee?Please refer the admission brochure 2017 and visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/
# 27. Is there any management quota?There is no management quota.
# 28. I passed class XII in 2016, can I apply?Yes, provided you satisfy the eligibility criteria.
# 29. When to apply for admission, etc.?For dates, please check the admission brochure 2017 and visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/.
# 30. Do you have any quota for sports, arts & culture or Olympiads?There is no quota for any of these categories. However, some bonus marks are given to applicants with specific achievements. For details, please refer admission brochure 2017 available on admission page.
# 31. Where can I get the details of UCEED?Please visit http://www.iitb.ac.in/uceed/2017/
# 32. Where can  I get the details of admission through IIITD Counselling?Please refer IIIT-D admission brochure
# 33. Is the transport facility (college bus) available?No we do not provide transport facility but IIIT-Delhi campus  is very  well connected to metro and other public transports.
# 34. Are there some seats for Foreign Nationals/PIOs/NRIsYes, Supernumerary seats are reserved for Foreign Nationals/PIOs/NRIs. For details click here.
# 35. How Outside Delhi Students can apply for admission to B.Tech programs at IIITD?Outside Delhi Students can apply only through Joint Admission Counseling, Delhi(JAC Delhi)
#
#
#
#
#
#
#
#
#
#
#
#
# =======================================
# =======================================
# heading=>  1. What is the status of IIIT-Delhi, is it recognized by UGC/AICTE, does it have any relationship with IP university, etc?
# text=>
# =======================================
# =======================================
# heading=>  2. What is the source of latest information about the Admission, Institute, etc.?
# text=>
# =======================================
# =======================================
# heading=>  3. When will the applications start?
# text=>
# =======================================
# =======================================
# heading=>  4. When and where will the list of selected candidates be displayed?
# text=>
# =======================================
# =======================================
# heading=>  Eligibility Related
# text=>  5. I got less than 80% in Mathematics in XII, but my overall marks are more than 80%, will I be eligible for admission in IIIT-Delhi ?No. A student is eligible only if he/she: (i) has obtained 80% or more in Mathematics, AND (ii) has obtained 80% or more aggregate score of best five subjects including maths.
# 6. I obtained 79.99% - am I eligible?No, you are not eligible for admissions in IIIT-Delhi even if your percentage is short by .1% or one mark.
# 7. I have taken Math, but have not done Physics or Chemistry in my XII Boards. I have got more than 80% in Math, and my overall percentage is also more than 80%. Am I eligible?Yes, you are eligible for admission to some seats of B.Tech(CSD) and B.Tech(ITSS) through UCEED and IIITD Counselling.
# 8.	I have 80% in Maths and 80% in aggregate which include Physics and Chemistry.  I want to apply to B.Tech.(CSD) and B.Tech.(ITSS). Which mode of admission should I apply through?Students having Physics, Chemistry and Mathematics in Class XII, willing to apply for B.Tech(CSD) program can apply through JAC and UCEED both. However, if at any point of time a candidate is getting a seat in both processes, he/she will have to withdraw one.Students having Physics, Chemistry and Mathematics in Class XII, willing to apply for B.Tech.(ITSS)  can apply only  through JAC.
# 9. I have done my XII from IB board. Am I eligible to apply?Yes, IB Board is considered equivalent to CBSE. However, before you are granted admission, you will have to show that you satisfy the eligibility criteria. If your Board does not give percentages, then you will have to show an official conversion to percentages.
# 10. Why is the eligibility criteria rather high in marks?To ensure that students have the necessary background in mathematics and overall, the eligibility criteria has been kept at this level. Another reason is that IIIT Delhi has very limited seats, and it is necessary to restrict the number of applicants to a reasonable number.
# 11. Are there any seats reserved for Central/State Board Topper candidates?No, none of the seats are reserved for Central/State Board Topper candidates.
# 12. Who is a “Delhi candidate”?The students who have undertaken qualifying exams (i.e. 12th) from the schools located in Delhi (having PIN CODE of Delhi), irrespective of the location of their hometown, would be considered as "Delhi Candidate". Students belonging to delhi but studying in schools outside delhi will be considered as outside delhi candidates.
# 13. Are schools located in Noida/Gurgaon and other places in NCR Delhi but outside New Delhi considered as Delhi school?No, "Delhi" candidates must have undertaken qualifying exams (i.e. XIIth) from the schools having PIN CODE of Delhi.
# 14. Whether students passing 12th as a private candidate (through open schooling) are eligible. If Yes, how their region i.e. Delhi or Outside Delhi will be determined.Yes, students passing 12th as a private candidate (through open schooling) are eligible to apply provided they satisfy other eligibility criteria. The region from which they can apply i.e. Delhi or Outside Delhi will be determined on the basis of the location of their examination centre.
# 15. I have taken up improvement exam and now have 80% or above marks in mathematics and aggregate. Can I apply?Yes, students who have taken up improvement exam and have now secured 80% or above marks in mathematics and aggregate are eligible to apply provided they satisfy all other eligibility criteria.
# 16. Can the expelled/debarred students be considered for admission?Students expelled from any academic institute are not eligible for admission.
# 17.  I don't have Computer Science in class 12th. Am I eligible for admission to B.Tech(CSE)?Yes, as far as you had mathematics, physics and chemistry as your Class XII standard subjects.
# 18. Can a student who has done schooling from Delhi apply under Outside Delhi Quota?No, if you have done XII from Delhi school you can apply as a Delhi candidate only
# 19. Is there any other source of information regarding the admissions other than the website?Website is the primary source of all the information regarding admission. Please also visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/ for details..
# 20. Any photocopy of the certificate need to be attached along with the application form or not?No certificates need to be sent - they will be checked at the time of counselling.
# 21. What is the source of latest information about the exam, Institute, etc.?Latest information is available on the Institute website. Pls also refer www.jacdelhi.nic.in  and http://www.iitb.ac.in/uceed/2017/.
# 22. Which degree will be awarded? What is the duration?IIIT Delhi awards B.Tech. (CSE), B.Tech(ECE), B.Tech (CSAM), B.Tech(CSD) and B.Tech(ITSS) degrees. The duration of the program is 4 years.
# 23. Where can I find the placement record?Placement record of the institute is available on the placement page of our website.
# 24. What is the fee per annum?Please refer B.Tech admission brochure 2017.
# 25. Is there any fee waiver?Please refer the B.Tech admission page and brochure 2017 for income-linked fee waivers/scholarships.
# 26. How do I pay the application fee?Please refer the admission brochure 2017 and visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/
# 27. Is there any management quota?There is no management quota.
# 28. I passed class XII in 2016, can I apply?Yes, provided you satisfy the eligibility criteria.
# 29. When to apply for admission, etc.?For dates, please check the admission brochure 2017 and visit www.jacdelhi.nic.in and http://www.iitb.ac.in/uceed/2017/.
# 30. Do you have any quota for sports, arts & culture or Olympiads?There is no quota for any of these categories. However, some bonus marks are given to applicants with specific achievements. For details, please refer admission brochure 2017 available on admission page.
# 31. Where can I get the details of UCEED?Please visit http://www.iitb.ac.in/uceed/2017/
# 32. Where can  I get the details of admission through IIITD Counselling?Please refer IIIT-D admission brochure
# 33. Is the transport facility (college bus) available?No we do not provide transport facility but IIIT-Delhi campus  is very  well connected to metro and other public transports.
# 34. Are there some seats for Foreign Nationals/PIOs/NRIsYes, Supernumerary seats are reserved for Foreign Nationals/PIOs/NRIs. For details click here.
# 35. How Outside Delhi Students can apply for admission to B.Tech programs at IIITD?Outside Delhi Students can apply only through Joint Admission Counseling, Delhi(JAC Delhi)
#
#
#
#
#
#
#
#
#
#
#
#
# =======================================
# =======================================
# heading=>  5. I got less than 80% in Mathematics in XII, but my overall marks are more than 80%, will I be eligible for admission in IIIT-Delhi ?
# text=>
# =======================================
# =======================================
# heading=>  6. I obtained 79.99% - am I eligible?
# text=>
# =======================================
# =======================================
# heading=>  7. I have taken Math, but have not done Physics or Chemistry in my XII Boards. I have got more than 80% in Math, and my overall percentage is also more than 80%. Am I eligible?
# text=>
# =======================================
# =======================================
# heading=>  8.	I have 80% in Maths and 80% in aggregate which include Physics and Chemistry.  I want to apply to B.Tech.(CSD) and B.Tech.(ITSS). Which mode of admission should I apply through?
# text=>
# =======================================
# =======================================
# heading=>  9. I have done my XII from IB board. Am I eligible to apply?
# text=>
# =======================================
# =======================================
# heading=>  10. Why is the eligibility criteria rather high in marks?
# text=>
# =======================================
# =======================================
# heading=>  11. Are there any seats reserved for Central/State Board Topper candidates?
# text=>
# =======================================
# =======================================
# heading=>  12. Who is a “Delhi candidate”?
# text=>
# =======================================
# =======================================
# heading=>  13. Are schools located in Noida/Gurgaon and other places in NCR Delhi but outside New Delhi considered as Delhi school?
# text=>
# =======================================
# =======================================
# heading=>  14. Whether students passing 12th as a private candidate (through open schooling) are eligible. If Yes, how their region i.e. Delhi or Outside Delhi will be determined.
# text=>
# =======================================
# =======================================
# heading=>  15. I have taken up improvement exam and now have 80% or above marks in mathematics and aggregate. Can I apply?
# text=>
# =======================================
# =======================================
# heading=>  16. Can the expelled/debarred students be considered for admission?
# text=>
# =======================================
# =======================================
# heading=>  17.  I don't have Computer Science in class 12th. Am I eligible for admission to B.Tech(CSE)?
# text=>
# =======================================
# =======================================
# heading=>  18. Can a student who has done schooling from Delhi apply under Outside Delhi Quota?
# text=>
# =======================================
# =======================================
# heading=>  19. Is there any other source of information regarding the admissions other than the website?
# text=>
# =======================================
# =======================================
# heading=>  20. Any photocopy of the certificate need to be attached along with the application form or not?
# text=>
# =======================================
# =======================================
# heading=>  21. What is the source of latest information about the exam, Institute, etc.?
# text=>
# =======================================
# =======================================
# heading=>  22. Which degree will be awarded? What is the duration?
# text=>
# =======================================
# =======================================
# heading=>  23. Where can I find the placement record?
# text=>
# =======================================
# =======================================
# heading=>  24. What is the fee per annum?
# text=>
# =======================================
# =======================================
# heading=>  25. Is there any fee waiver?
# text=>
# =======================================
# =======================================
# heading=>  26. How do I pay the application fee?
# text=>
# =======================================
# =======================================
# heading=>  27. Is there any management quota?
# text=>
# =======================================
# =======================================
# heading=>  28. I passed class XII in 2016, can I apply?
# text=>
# =======================================
# =======================================
# heading=>  29. When to apply for admission, etc.?
# text=>
# =======================================
# =======================================
# heading=>  30. Do you have any quota for sports, arts & culture or Olympiads?
# text=>
# =======================================
# =======================================
# heading=>  31. Where can I get the details of UCEED?
# text=>
# =======================================
# =======================================
# heading=>  32. Where can  I get the details of admission through IIITD Counselling?
# text=>
# =======================================
# =======================================
# heading=>  33. Is the transport facility (college bus) available?
# text=>
# =======================================
# =======================================
# heading=>  34. Are there some seats for Foreign Nationals/PIOs/NRIs
# text=>
# =======================================
# =======================================
# heading=>  35. How Outside Delhi Students can apply for admission to B.Tech programs at IIITD?
# text=>
# =======================================
# *********done for  76.txt

# %%
link = "http://iiitd.ac.in/research/publications-to"


def flattenlist(nonfllist):
    import collections
    for val in nonfllist:
        if not isinstance(val, (str,bytes)) and isinstance(val , collections.Iterable):
            yield from flattenlist(val)
        else:
            yield val



val = link.split('/')
t = 'iiitd.ac.in'
ind = val.index(t)
tags = [val[i] for i in range(ind+1,len(val))]
tags = [c.split('-') for c in tags]

tags = list(flattenlist(tags))
tags
# Out:
# ['research', 'publications', 'to']
